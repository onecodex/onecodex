# %%
from onecodex.api import Api
from onecodex.viz import *
ocx = Api(base_url="http://localhost:3000", api_key='25d75fc1d7744c8f83002a4fa5f84502')

# %%
a = ocx.Classifications.get('f88503b592ea4cb1')
b = ocx.Classifications.get('92f8dbd18b6b4945')
c = ocx.Classifications.get('3da5634225b9479b')
d = ocx.Classifications.get('6815a2ee9f1b40fa')

# %%
from onecodex.viz.helpers import collate_analysis_results
df = collate_analysis_results([a, b], metric='readcount')
df.columns = ['{} ({})'.format(v[1], v[0]) for v in df.columns.values]
df
# Out:
#                   Root (1)  Flexibacter roseolus (1002)  \
# 92f8dbd18b6b4945       4.0                          0.0
# f88503b592ea4cb1       8.0                          1.0
#
#                   Flexibacter ruber (1003)  Verrucosispora maris (1003110)  \
# 92f8dbd18b6b4945                       0.0                             0.0
# f88503b592ea4cb1                      13.0                             8.0
#
#                   Photorhabdus temperata subsp. khanii NC19 (1004151)  \
# 92f8dbd18b6b4945                                                3.0
# f88503b592ea4cb1                                                0.0
#
#                   Photorhabdus temperata subsp. tasmaniensis (1004159)  \
# 92f8dbd18b6b4945                                                0.0
# f88503b592ea4cb1                                                3.0
#
#                   Fimbriimonas ginsengisoli (1005039)  \
# 92f8dbd18b6b4945                                  0.0
# ...

# %%
df.sum(axis=0).sort_values(ascending=False)
# Out:
# Shewanella baltica OS678 (693973)                            157366.0
# Shewanella (22)                                              157286.0
# Salinispora (168694)                                         104795.0
# Methanococcus maripaludis (39152)                            104502.0
# Methanococcus maripaludis C7 (426368)                        104346.0
# Bacteroides (816)                                            102741.0
# Persephonella marina EX-H1 (123214)                           97530.0
# Thermotoga (2335)                                             94336.0
# Akkermansia muciniphila ATCC BAA-835 (349741)                 64553.0
# Akkermansia muciniphila (239935)                              64474.0
# Sulfurihydrogenibium (212790)                                 62586.0
# Sulfurihydrogenibium azorense Az-Fu1 (204536)                 61321.0
# Desulfovibrio piger (901)                                     60932.0
# ...

# %%
analyses = [a, c]
plot_heatmap(analyses, metric='readcount')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-4-1ff5b787a78c> in <module>()
#       1 analyses = [a, c]
# ----> 2 plot_heatmap(analyses, top_n=10, metric='readcount')
#
# ~/Desktop/onecodex/onecodex/viz/heatmap.py in plot_heatmap(analyses, title, threshold, top_n, metric)
#      25         g = seaborn.clustermap(df.loc[:, df.max() >= threshold])
#      26     elif top_n:
# ---> 27         g = seaborn.clustermap(df.iloc[:top_n].sort_values(df.max()))
#      28
#      29     # Rotate the margin labels
#
# ~/Desktop/onecodex/venv/lib/python3.6/site-packages/pandas/core/frame.py in sort_values(self, by, axis, ascending, inplace, kind, na_position)
#    3184
#    3185             by = by[0]
# -> 3186             k = self.xs(by, axis=other_axis).values
#    3187             if k.ndim == 2:
#    3188
#
# ...
